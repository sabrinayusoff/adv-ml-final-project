# %% [markdown]
# # Predicting the Round of a Jeopardy! Question using Logistic Regression

# %% [markdown]
# In this notebook, we aim to build a classification model that takes a Jeopardy! question as input and predicts the round for which the question was posed. Round is used as a proxy for question difficulty.

# %%
import torch
import torchtext
import torchdata
import portalocker
import json
import pandas as pd
from torch.utils.data import Dataset
from torch.utils.data import TensorDataset, DataLoader
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

# %%
filename = 'jeopardy_csv.csv'

with open(filename, 'r', encoding='iso-8859-1') as f:
    df = pd.read_csv(f)

df
# Out:
#         Show Number    Air Date             Round
# 0              4680  2004-12-31         Jeopardy!  \
# 1              4680  2004-12-31         Jeopardy!
# 2              4680  2004-12-31         Jeopardy!
# 3              4680  2004-12-31         Jeopardy!
# 4              4680  2004-12-31         Jeopardy!
# ...             ...         ...               ...
# 216925         4999  2006-05-11  Double Jeopardy!
# 216926         4999  2006-05-11  Double Jeopardy!
# 216927         4999  2006-05-11  Double Jeopardy!
# 216928         4999  2006-05-11  Double Jeopardy!
# 216929         4999  2006-05-11   Final Jeopardy!
#
#                                Category  Value
# 0                               HISTORY   $200  \
# 1       ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2           EVERYBODY TALKS ABOUT IT...   $200
# 3                      THE COMPANY LINE   $200
# 4                   EPITAPHS & TRIBUTES   $200
# ...                                 ...    ...
# 216925                   RIDDLE ME THIS  $2000
# 216926                        "T" BIRDS  $2000
# 216927           AUTHORS IN THEIR YOUTH  $2000
# 216928                       QUOTATIONS  $2000
# 216929                   HISTORIC NAMES    NaN
#
#                                                  Question
# 0       For the last 8 years of his life, Galileo was ...  \
# 1       No. 2: 1912 Olympian; football star at Carlisl...
# 2       The city of Yuma in this state has a record av...
# 3       In 1963, live on "The Art Linkletter Show", th...
# 4       Signer of the Dec. of Indep., framer of the Co...
# ...                                                   ...
# 216925  This Puccini opera turns on the solution to 3 ...
# 216926  In North America this term is properly applied...
# 216927  In Penny Lane, where this "Hellraiser" grew up...
# 216928  From Ft. Sill, Okla. he made the plea, Arizona...
# 216929  A silent movie title includes the last name of...
#
#                                 Answer
# 0                           Copernicus
# 1                           Jim Thorpe
# 2                              Arizona
# 3                           McDonald's
# 4                           John Adams
# ...                                ...
# 216925                        Turandot
# 216926                      a titmouse
# 216927                    Clive Barker
# 216928                        Geronimo
# 216929  Grigori Alexandrovich Potemkin
#
# [216930 rows x 7 columns]

# %% [markdown]
# Round lables:
# 0 - Jeopardy!
# 1 - Double Jeopardy!
# 2 - Final Jeopardy!
# 3 - Tiebreaker

# %%
df = df[[' Round', ' Question']]
df = df.rename(columns={' Question': 'Question',' Round': 'Round'})
df.head()
# Out:
#        Round                                           Question
# 0  Jeopardy!  For the last 8 years of his life, Galileo was ...
# 1  Jeopardy!  No. 2: 1912 Olympian; football star at Carlisl...
# 2  Jeopardy!  The city of Yuma in this state has a record av...
# 3  Jeopardy!  In 1963, live on "The Art Linkletter Show", th...
# 4  Jeopardy!  Signer of the Dec. of Indep., framer of the Co...

# %%
rounds = {'Jeopardy!': 0, 'Double Jeopardy!': 1, 'Final Jeopardy!': 2, 'Tiebreaker': 3}

df['ENCODE_ROUND'] = df['Round'].apply(lambda x: rounds[x])
df['ENCODE_ROUND'].unique()
df
# Out:
#                    Round                                           Question
# 0              Jeopardy!  For the last 8 years of his life, Galileo was ...  \
# 1              Jeopardy!  No. 2: 1912 Olympian; football star at Carlisl...
# 2              Jeopardy!  The city of Yuma in this state has a record av...
# 3              Jeopardy!  In 1963, live on "The Art Linkletter Show", th...
# 4              Jeopardy!  Signer of the Dec. of Indep., framer of the Co...
# ...                  ...                                                ...
# 216925  Double Jeopardy!  This Puccini opera turns on the solution to 3 ...
# 216926  Double Jeopardy!  In North America this term is properly applied...
# 216927  Double Jeopardy!  In Penny Lane, where this "Hellraiser" grew up...
# 216928  Double Jeopardy!  From Ft. Sill, Okla. he made the plea, Arizona...
# 216929   Final Jeopardy!  A silent movie title includes the last name of...
#
#         ENCODE_ROUND
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 216925             1
# 216926             1
# 216927             1
# 216928             1
# 216929             2
#
# [216930 rows x 3 columns]

# %%
df
# Out:
#                    Round                                           Question
# 0              Jeopardy!  For the last 8 years of his life, Galileo was ...  \
# 1              Jeopardy!  No. 2: 1912 Olympian; football star at Carlisl...
# 2              Jeopardy!  The city of Yuma in this state has a record av...
# 3              Jeopardy!  In 1963, live on "The Art Linkletter Show", th...
# 4              Jeopardy!  Signer of the Dec. of Indep., framer of the Co...
# ...                  ...                                                ...
# 216925  Double Jeopardy!  This Puccini opera turns on the solution to 3 ...
# 216926  Double Jeopardy!  In North America this term is properly applied...
# 216927  Double Jeopardy!  In Penny Lane, where this "Hellraiser" grew up...
# 216928  Double Jeopardy!  From Ft. Sill, Okla. he made the plea, Arizona...
# 216929   Final Jeopardy!  A silent movie title includes the last name of...
#
#         ENCODE_ROUND
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 216925             1
# 216926             1
# 216927             1
# 216928             1
# 216929             2
#
# [216930 rows x 3 columns]

# %%
# split into train, valid and test dataset
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df, train_size=0.9, test_size=0.1, random_state = 200)

# %%
train_iter = iter(train_data.Question)

# %%
tokenizer = get_tokenizer('basic_english')
def yield_tokens(train_iter):
    for text in train_iter:
        yield tokenizer(text)

vocab = build_vocab_from_iterator(
    yield_tokens(train_iter), specials=["<unk>"], min_freq=1000)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tokenizer = get_tokenizer('basic_english')

tfidf_vectorizer = TfidfVectorizer(tokenizer=tokenizer, max_features=len(vocab))
tfidf_vectorizer.fit(train_data['Question'])

inputs = tfidf_vectorizer.transform(train_data['Question'])
# Out:
# c:\Users\sabri\.conda\envs\capp30255\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
test_inputs = tfidf_vectorizer.transform(test_data['Question'])

# %%
# split training data further into train and validation set
targets = train_data.ENCODE_ROUND
train_inputs, val_inputs, train_targets, val_targets = train_test_split(inputs, targets, test_size = 0.2)
test_targets = test_data.ENCODE_ROUND

# %%
# convert into pytorch tensors
train_input_tensors = torch.tensor(train_inputs.toarray()).float()
val_input_tensors = torch.tensor(val_inputs.toarray()).float()
test_input_tensors = torch.tensor(test_inputs.toarray()).float()

train_target_tensors = torch.tensor(train_targets.values)
val_target_tensors = torch.tensor(val_targets.values)
test_target_tensors = torch.tensor(test_targets.values)

# %%
# create dataloaders
BATCH_SIZE = 64

train_ds = TensorDataset(train_target_tensors, train_input_tensors)
val_ds = TensorDataset(val_target_tensors, val_input_tensors)
test_ds = TensorDataset(test_target_tensors, test_input_tensors)

train_dataloader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=True)

# %%
from torch import nn
import torch.nn.functional as F

class TFIDFClassifier(nn.Module):
    def __init__(self, num_labels, vocab_size):
        super(TFIDFClassifier, self).__init__()
        self.linear = nn.Linear(vocab_size, num_labels)
    
    def forward(self, vec):
        return F.log_softmax(self.linear(vec), dim=1)

# %%
num_labels = 4
vocab_size = len(vocab)
model = TFIDFClassifier(num_labels, vocab_size)

# %% [markdown]
# ### Create function to train one epoch

# %%
import time

loss_function = torch.nn.NLLLoss()

def train_an_epoch(dataloader, optimizer):
    model.train() # Sets the module in training mode.
    log_interval = 500

    for idx, (label, text) in enumerate(dataloader):
        model.zero_grad()
        log_probs = model(text) # forward pass
        loss = loss_function(log_probs, label)
        loss.backward()
        optimizer.step()
        if idx % log_interval == 0 and idx > 0:
            print(f'At iteration {idx} the loss is {loss:.3f}.')

# %% [markdown]
# ### Create function to compute accuracy

# %%
def get_accuracy(dataloader):
    model.eval() # switch to indicate that the model is not in training mode
    with torch.no_grad(): # disables gradient calculation (for when you are sure you will not call Tensor.backward()). This will reduce memory consumption.
        total_examples = 0
        correct = 0
        for labels, text in dataloader: # for each batch in dataloader
            total_examples += text.shape[0]
            probs = model(text)
            preds = probs.argmax(1)
            correct += (torch.eq(preds, labels)).sum().item()
        overall_accuracy = correct / total_examples
        return overall_accuracy

# %% [markdown]
# ### Training

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

EPOCHS = 50
optimizer = torch.optim.SGD(model.parameters(), lr=3)

accuracies=[]
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train_an_epoch(train_dataloader, optimizer)
    accuracy = get_accuracy(valid_dataloader)
    accuracies.append(accuracy)
    time_taken = time.time() - epoch_start_time
    print()
    print(f'After epoch {epoch} the validation accuracy is {accuracy:.3f}.')
    print()
    
plt.plot(range(1, EPOCHS+1), accuracies)
# Out:
# At iteration 500 the loss is 0.861.
# At iteration 1000 the loss is 0.729.
# At iteration 1500 the loss is 0.793.
# At iteration 2000 the loss is 0.720.
#
# After epoch 1 the validation accuracy is 0.485.
#
# At iteration 500 the loss is 0.824.
# At iteration 1000 the loss is 0.781.
# At iteration 1500 the loss is 0.847.
# At iteration 2000 the loss is 0.735.
#
# After epoch 2 the validation accuracy is 0.510.
#
# At iteration 500 the loss is 0.721.
# At iteration 1000 the loss is 0.868.
# At iteration 1500 the loss is 0.725.
# At iteration 2000 the loss is 0.775.
#
# After epoch 3 the validation accuracy is 0.493.
#
# At iteration 500 the loss is 0.771.
# At iteration 1000 the loss is 0.759.
# At iteration 1500 the loss is 0.785.
# At iteration 2000 the loss is 0.715.
#
# After epoch 4 the validation accuracy is 0.498.
#
# At iteration 500 the loss is 0.751.
# At iteration 1000 the loss is 0.850.
# At iteration 1500 the loss is 0.848.
# At iteration 2000 the loss is 0.750.
#
# After epoch 5 the validation accuracy is 0.533.
#
# At iteration 500 the loss is 0.847.
# At iteration 1000 the loss is 0.691.
# At iteration 1500 the loss is 0.661.
# At iteration 2000 the loss is 0.737.
#
# After epoch 6 the validation accuracy is 0.502.
#
# At iteration 500 the loss is 0.755.
# At iteration 1000 the loss is 0.850.
# At iteration 1500 the loss is 0.772.
# At iteration 2000 the loss is 0.759.
#
# After epoch 7 the validation accuracy is 0.521.
#
# At iteration 500 the loss is 0.765.
# At iteration 1000 the loss is 0.744.
# At iteration 1500 the loss is 0.826.
# At iteration 2000 the loss is 0.695.
#
# After epoch 8 the validation accuracy is 0.499.
#
# At iteration 500 the loss is 0.737.
# At iteration 1000 the loss is 0.783.
# At iteration 1500 the loss is 0.733.
# At iteration 2000 the loss is 0.767.
#
# After epoch 9 the validation accuracy is 0.540.
#
# At iteration 500 the loss is 0.766.
# At iteration 1000 the loss is 0.726.
# At iteration 1500 the loss is 0.761.
# At iteration 2000 the loss is 0.733.
#
# After epoch 10 the validation accuracy is 0.528.
#
# At iteration 500 the loss is 0.721.
# At iteration 1000 the loss is 0.669.
# At iteration 1500 the loss is 0.840.
# At iteration 2000 the loss is 0.789.
#
# After epoch 11 the validation accuracy is 0.486.
#
# At iteration 500 the loss is 0.733.
# At iteration 1000 the loss is 0.810.
# At iteration 1500 the loss is 0.748.
# At iteration 2000 the loss is 0.713.
#
# After epoch 12 the validation accuracy is 0.500.
#
# At iteration 500 the loss is 0.806.
# At iteration 1000 the loss is 0.772.
# At iteration 1500 the loss is 0.829.
# At iteration 2000 the loss is 0.775.
#
# After epoch 13 the validation accuracy is 0.532.
#
# At iteration 500 the loss is 0.950.
# At iteration 1000 the loss is 0.837.
# At iteration 1500 the loss is 0.831.
# At iteration 2000 the loss is 0.757.
#
# After epoch 14 the validation accuracy is 0.496.
#
# At iteration 500 the loss is 0.911.
# At iteration 1000 the loss is 0.882.
# At iteration 1500 the loss is 0.711.
# At iteration 2000 the loss is 0.982.
#
# After epoch 15 the validation accuracy is 0.530.
#
# At iteration 500 the loss is 0.794.
# At iteration 1000 the loss is 0.819.
# At iteration 1500 the loss is 0.773.
# At iteration 2000 the loss is 0.768.
#
# After epoch 16 the validation accuracy is 0.500.
#
# At iteration 500 the loss is 0.774.
# At iteration 1000 the loss is 0.796.
# At iteration 1500 the loss is 0.741.
# At iteration 2000 the loss is 0.681.
#
# After epoch 17 the validation accuracy is 0.511.
#
# At iteration 500 the loss is 0.854.
# At iteration 1000 the loss is 0.787.
# At iteration 1500 the loss is 0.689.
# At iteration 2000 the loss is 0.847.
#
# After epoch 18 the validation accuracy is 0.499.
#
# At iteration 500 the loss is 0.760.
# At iteration 1000 the loss is 0.784.
# At iteration 1500 the loss is 0.764.
# At iteration 2000 the loss is 0.716.
#
# After epoch 19 the validation accuracy is 0.523.
#
# At iteration 500 the loss is 0.751.
# At iteration 1000 the loss is 0.850.
# At iteration 1500 the loss is 0.780.
# At iteration 2000 the loss is 0.695.
#
# After epoch 20 the validation accuracy is 0.538.
#
# At iteration 500 the loss is 0.766.
# At iteration 1000 the loss is 0.756.
# At iteration 1500 the loss is 0.719.
# At iteration 2000 the loss is 0.852.
#
# After epoch 21 the validation accuracy is 0.534.
#
# At iteration 500 the loss is 0.870.
# At iteration 1000 the loss is 0.759.
# At iteration 1500 the loss is 0.718.
# At iteration 2000 the loss is 0.791.
#
# After epoch 22 the validation accuracy is 0.534.
#
# At iteration 500 the loss is 0.876.
# At iteration 1000 the loss is 0.818.
# At iteration 1500 the loss is 0.752.
# At iteration 2000 the loss is 0.807.
#
# After epoch 23 the validation accuracy is 0.528.
#
# At iteration 500 the loss is 0.852.
# At iteration 1000 the loss is 0.681.
# At iteration 1500 the loss is 0.708.
# At iteration 2000 the loss is 0.754.
#
# After epoch 24 the validation accuracy is 0.534.
#
# At iteration 500 the loss is 0.755.
# At iteration 1000 the loss is 0.758.
# At iteration 1500 the loss is 0.738.
# At iteration 2000 the loss is 0.740.
#
# After epoch 25 the validation accuracy is 0.485.
#
# At iteration 500 the loss is 0.960.
# At iteration 1000 the loss is 0.756.
# At iteration 1500 the loss is 0.812.
# At iteration 2000 the loss is 0.697.
#
# After epoch 26 the validation accuracy is 0.520.
#
# At iteration 500 the loss is 0.737.
# At iteration 1000 the loss is 0.770.
# At iteration 1500 the loss is 0.816.
# At iteration 2000 the loss is 0.724.
#
# After epoch 27 the validation accuracy is 0.538.
#
# At iteration 500 the loss is 0.851.
# At iteration 1000 the loss is 0.798.
# At iteration 1500 the loss is 0.687.
# At iteration 2000 the loss is 0.740.
#
# After epoch 28 the validation accuracy is 0.488.
#
# At iteration 500 the loss is 0.721.
# At iteration 1000 the loss is 0.785.
# At iteration 1500 the loss is 0.744.
# At iteration 2000 the loss is 0.935.
#
# After epoch 29 the validation accuracy is 0.507.
#
# At iteration 500 the loss is 0.748.
# At iteration 1000 the loss is 0.705.
# At iteration 1500 the loss is 0.786.
# At iteration 2000 the loss is 0.712.
#
# After epoch 30 the validation accuracy is 0.488.
#
# At iteration 500 the loss is 0.748.
# At iteration 1000 the loss is 0.754.
# At iteration 1500 the loss is 0.705.
# At iteration 2000 the loss is 0.732.
#
# After epoch 31 the validation accuracy is 0.528.
#
# At iteration 500 the loss is 0.674.
# At iteration 1000 the loss is 0.828.
# At iteration 1500 the loss is 0.809.
# At iteration 2000 the loss is 0.808.
#
# After epoch 32 the validation accuracy is 0.518.
#
# At iteration 500 the loss is 0.756.
# At iteration 1000 the loss is 0.721.
# At iteration 1500 the loss is 0.758.
# At iteration 2000 the loss is 0.776.
#
# After epoch 33 the validation accuracy is 0.500.
#
# At iteration 500 the loss is 0.704.
# At iteration 1000 the loss is 0.823.
# At iteration 1500 the loss is 0.776.
# At iteration 2000 the loss is 0.894.
#
# After epoch 34 the validation accuracy is 0.517.
#
# At iteration 500 the loss is 0.701.
# At iteration 1000 the loss is 0.805.
# At iteration 1500 the loss is 0.684.
# At iteration 2000 the loss is 0.675.
#
# After epoch 35 the validation accuracy is 0.506.
#
# At iteration 500 the loss is 0.691.
# At iteration 1000 the loss is 0.807.
# At iteration 1500 the loss is 0.711.
# At iteration 2000 the loss is 0.736.
#
# After epoch 36 the validation accuracy is 0.493.
#
# At iteration 500 the loss is 0.808.
# At iteration 1000 the loss is 0.774.
# At iteration 1500 the loss is 0.704.
# At iteration 2000 the loss is 0.793.
#
# After epoch 37 the validation accuracy is 0.492.
#
# At iteration 500 the loss is 0.785.
# At iteration 1000 the loss is 0.760.
# At iteration 1500 the loss is 0.757.
# At iteration 2000 the loss is 0.835.
#
# After epoch 38 the validation accuracy is 0.532.
#
# At iteration 500 the loss is 0.820.
# At iteration 1000 the loss is 0.735.
# At iteration 1500 the loss is 0.757.
# At iteration 2000 the loss is 0.766.
#
# After epoch 39 the validation accuracy is 0.501.
#
# At iteration 500 the loss is 0.783.
# At iteration 1000 the loss is 0.800.
# At iteration 1500 the loss is 0.732.
# At iteration 2000 the loss is 0.791.
#
# After epoch 40 the validation accuracy is 0.523.
#
# At iteration 500 the loss is 0.875.
# At iteration 1000 the loss is 0.773.
# At iteration 1500 the loss is 0.833.
# At iteration 2000 the loss is 0.885.
#
# After epoch 41 the validation accuracy is 0.529.
#
# At iteration 500 the loss is 0.787.
# At iteration 1000 the loss is 0.754.
# At iteration 1500 the loss is 0.935.
# At iteration 2000 the loss is 0.704.
#
# After epoch 42 the validation accuracy is 0.485.
#
# At iteration 500 the loss is 0.870.
# At iteration 1000 the loss is 0.741.
# At iteration 1500 the loss is 0.655.
# At iteration 2000 the loss is 0.730.
#
# After epoch 43 the validation accuracy is 0.535.
#
# At iteration 500 the loss is 0.680.
# At iteration 1000 the loss is 0.802.
# At iteration 1500 the loss is 0.745.
# At iteration 2000 the loss is 0.748.
#
# After epoch 44 the validation accuracy is 0.502.
#
# At iteration 500 the loss is 0.837.
# At iteration 1000 the loss is 0.737.
# At iteration 1500 the loss is 0.779.
# At iteration 2000 the loss is 0.776.
#
# After epoch 45 the validation accuracy is 0.535.
#
# At iteration 500 the loss is 0.834.
# At iteration 1000 the loss is 0.742.
# At iteration 1500 the loss is 0.825.
# At iteration 2000 the loss is 0.835.
#
# After epoch 46 the validation accuracy is 0.485.
#
# At iteration 500 the loss is 0.799.
# At iteration 1000 the loss is 0.679.
# At iteration 1500 the loss is 0.832.
# At iteration 2000 the loss is 0.699.
#
# After epoch 47 the validation accuracy is 0.486.
#
# At iteration 500 the loss is 0.715.
# At iteration 1000 the loss is 0.798.
# At iteration 1500 the loss is 0.728.
# At iteration 2000 the loss is 0.812.
#
# After epoch 48 the validation accuracy is 0.525.
#
# At iteration 500 the loss is 0.717.
# At iteration 1000 the loss is 0.743.
# At iteration 1500 the loss is 0.686.
# At iteration 2000 the loss is 0.825.
#
# After epoch 49 the validation accuracy is 0.516.
#
# At iteration 500 the loss is 0.731.
# At iteration 1000 the loss is 0.839.
# At iteration 1500 the loss is 0.752.
# At iteration 2000 the loss is 0.773.
#
# After epoch 50 the validation accuracy is 0.489.

# %%
test_accuracy = get_accuracy(test_dataloader)
print("test accuracy from model trained on 50 epochs:", test_accuracy)
# Out:
# test accuracy from model trained on 50 epochs: 0.4927395934172314

# %%
test_data.Round.unique()
# Out:
# array(['Double Jeopardy!', 'Jeopardy!', 'Final Jeopardy!'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import numpy as np

y_pred = []
y_true = []

# iterate over test data
for labels, inputs in test_dataloader:
        output = model(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# constant for classes (only three because there were no instances of Tiebreaker in the test data)
classes = ('Jeopardy!', 'Double Jeopardy!', 'Final Jeopardy!')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.savefig('output.png')
